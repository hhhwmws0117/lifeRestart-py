# %%
# !git clone https://github.com/hhhwmws0117/lifeRestart-py.git
# Out:
# Cloning into 'lifeRestart-py'...
# remote: Enumerating objects: 161, done.
# remote: Counting objects: 100% (97/97), done.
# remote: Compressing objects: 100% (30/30), done.
# remote: Total 161 (delta 74), reused 67 (delta 67), pack-reused 64
# Receiving objects: 100% (161/161), 222.10 KiB | 7.93 MiB/s, done.
# Resolving deltas: 100% (93/93), done.

# %%
# %cd lifeRestart-py

# !python LifeStart.py
# Out:
# /content/lifeRestart-py
#
# 【选择天赋】
# 1.足量（身高不矮）
# 2.旅行者（你喜欢旅游）
# 3.时光倒流（或许时间会倒流）
# 4.不想罢了（你不会上清华大学）
# 5.天秤座（据说做事很公平）
# 6.红颜薄命（颜值+2，体质-2）
# 7.健康饮食（你不吃洋快餐）
# 8.献祭（初始可用属性点-2，快乐+2）
# 9.乐观（快乐+1）
# 10.随身玉佩（或许有护佑作用）
# 从中挑选一个你想拥有的天赋并输入序号（默认选择1）：10
# 你选择了：随身玉佩（或许有护佑作用）
#
# 【选择天赋】
# 1.足量（身高不矮）
# 2.旅行者（你喜欢旅游）
# 3.时光倒流（或许时间会倒流）
# 4.不想罢了（你不会上清华大学）
# 5.天秤座（据说做事很公平）
# 6.红颜薄命（颜值+2，体质-2）
# 7.健康饮食（你不吃洋快餐）
# 8.献祭（初始可用属性点-2，快乐+2）
# 9.乐观（快乐+1）
# 从中挑选一个你想拥有的天赋并输入序号（默认选择1）：3
# 你选择了：时光倒流（或许时间会倒流）
#
# 【选择天赋】
# 1.足量（身高不矮）
# 2.旅行者（你喜欢旅游）
# 3.不想罢了（你不会上清华大学）
# 4.天秤座（据说做事很公平）
# 5.红颜薄命（颜值+2，体质-2）
# 6.健康饮食（你不吃洋快餐）
# 7.献祭（初始可用属性点-2，快乐+2）
# 8.乐观（快乐+1）
# 从中挑选一个你想拥有的天赋并输入序号（默认选择1）：2
# 你选择了：旅行者（你喜欢旅游）
#
# 【第1轮开始】获得以下天赋：
# 随身玉佩（或许有护佑作用）
# 时光倒流（或许时间会倒流）
# 旅行者（你喜欢旅游）
# 属性：颜值7 智力5 体质1 家境7 快乐5
#
# 【0岁/颜7智5体1钱7乐5】你出生了，是个男孩。——天赋【随身玉佩】发动：或许有护佑作用——天赋【时光倒流】发动：或许时间会倒流——天赋【旅行者】发动：你喜欢旅游
#
# 【1岁/颜7智5体1钱7乐5】你从小生活在城市
#
# 【2岁/颜7智5体1钱7乐5】你进入了托儿所。
#
# 【3岁/颜7智5体1钱7乐5】你上了一个普通的幼儿园。
#
# 【4岁/颜7智5体1钱7乐5】上课时，你很乖，坐姿端正。
#
# ...
